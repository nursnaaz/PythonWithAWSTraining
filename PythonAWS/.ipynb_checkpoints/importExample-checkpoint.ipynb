# %%
import math
len(globals())
# Out:
# 23

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
import math as m
len(globals())
# Out:
# 28

# %%
m.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt
len(globals())
# Out:
# 33

# %%
from math import *
len(globals())
# Out:
# 83

# %%
sqrt(4)
# Out:
# 2.0

# %%
def sqrt(x):
    return x*x

# %%
print (sqrt(25))
# Out:
# 625
